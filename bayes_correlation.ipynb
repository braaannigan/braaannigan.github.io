# %%
import numpy as np
#import matplotlib.pyplot as plt
import holoviews as hv
hv.notebook_extension()
# Out:
# <script src="https://code.jquery.com/ui/1.10.4/jquery-ui.min.js" type="text/javascript"></script>
# <script type="text/javascript">function HoloViewsWidget(){
# }
#
# HoloViewsWidget.comms = {};
# HoloViewsWidget.comm_state = {};
#
# HoloViewsWidget.prototype.init_slider = function(init_val){
# 	if(this.load_json) {
# 		this.from_json()
# 	} else {
# 		this.update_cache();
# 	}
# }
#
# HoloViewsWidget.prototype.populate_cache = function(idx){
#     this.cache[idx].html(this.frames[idx]);
#     if (this.embed) {
#         delete this.frames[idx];
#     }
# }
#
# HoloViewsWidget.prototype.process_error = function(msg){
#
# }
#
# HoloViewsWidget.prototype.from_json = function() {
# 	var data_url = this.json_path + this.id + '.json';
# 	$.getJSON(data_url, $.proxy(function(json_data) {
# 		this.frames = json_data;
# 		this.update_cache();
# 		this.update(0);
# 	}, this));
# }
#
# HoloViewsWidget.prototype.dynamic_update = function(current){
# 	if (current === undefined) {
# 		return
# ...

# %%
N = 30
corr_int = 100
mu1 = 0
mu2 = 0
means = np.array([ mu1, mu2])

var1 = 1
var2 = 1

rho = np.arange(-1,1,1e-2)
data = np.empty( (N, 2, len( rho ) ) )
for idx,r in enumerate( rho ):
    covs = np.array( [[var1**2,r*var1*var2],[r*var1*var2, var2**2]])
    data[:,:,idx] = np.random.multivariate_normal( means, covs, N)

# %% [markdown]
# scatter = hv.Points(data)
# scatter

# %%
np.random.seed(10)
data = np.random.rand(100,4)

scatter = hv.Scatter(data)

# %%
dictionary = {r:hv.Scatter(data[:,:,idx]) 
              for idx,r in enumerate(rho)} #np.arange(len(rho))}
scatter = hv.HoloMap(dictionary, kdims=['Rho'])
scatter

# %%
plt.scatter(data[:,0,51],data[:,1,51])
plt.show()

# %%
np.random.seed(42)
coords = [(i, np.random.random()) for i in range(20)]
hv.Scatter(coords)
# Out:
# :Scatter   [x]   (y)

# %%
coords[0]
# Out:
# (0, 0.3745401188473625)
